# %% [markdown]
# # **Comparison with other countries**

# %% [markdown]
# >In the previous Notebooks, a scientific method using the SIRD model has been implemented and studied to become powerful enough to modelize the reality of Covid-19 in whole Brazil, finding optimal parameters for each State. \\
# >In this Notebook, a proposition to apply this process to other countries, then compare the results each other is exposed.

# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from scipy import optimize
import plotly.graph_objects as go
import yaml
from datetime import datetime

# %% [markdown]
# ## Loading

# %%
# Data importation from CSSE and Johns Hopkins University
data_path = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv'
data_table = pd.read_csv(data_path, delimiter=",")
data_table.head()
# Out:
#   Province/State Country/Region       Lat  ...  4/19/21  4/20/21  4/21/21
# 0            NaN    Afghanistan  33.93911  ...    52244    52272    52301
# 1            NaN        Albania  41.15330  ...   102171   102601   103066
# 2            NaN        Algeria  28.03390  ...    83514    83636    83765
# 3            NaN        Andorra  42.50630  ...    12203    12285    12334
# 4            NaN         Angola -11.20270  ...    22600    22647    22882
#
# [5 rows x 460 columns]

# %% [markdown]
# ## France

# %% [markdown]
# ## Germany

# %% [markdown]
# ## Italy

# %% [markdown]
# ## United Kingdom

# %% [markdown]
# ## China
